# %%
import math
import os
import requests
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.api.types import is_numeric_dtype

import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

pd.set_option('display.float_format',lambda x: f"{x:,.2f}")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 100)

from IPython.display import display, HTML
# display(HTML(data.to_html(index = False)))

# %%
# data from https://www.kaggle.com/datasets/davinwijaya/customer-retention
# y: conversion
# treatment: offer

# %%
data = pd.read_csv('../data/customer_retention/data.csv')

# %%
data.describe(include = 'all')
# Out:
#          recency   history  used_discount  used_bogo   zip_code  is_referral  \
# count  64,000.00 64,000.00      64,000.00  64,000.00      64000    64,000.00
# unique       NaN       NaN            NaN        NaN          3          NaN
# top          NaN       NaN            NaN        NaN  Surburban          NaN
# freq         NaN       NaN            NaN        NaN      28776          NaN
# mean        5.76    242.09           0.55       0.55        NaN         0.50
# std         3.51    256.16           0.50       0.50        NaN         0.50
# min         1.00     29.99           0.00       0.00        NaN         0.00
# 25%         2.00     64.66           0.00       0.00        NaN         0.00
# 50%         6.00    158.11           1.00       1.00        NaN         1.00
# 75%         9.00    325.66           1.00       1.00        NaN         1.00
# max        12.00  3,345.93           1.00       1.00        NaN         1.00
#
#        channel            offer  conversion
# count    64000            64000   64,000.00
# unique       3                3         NaN
# top        Web  Buy One Get One         NaN
# freq     28217            21387         NaN
# mean       NaN              NaN        0.15
# std        NaN              NaN        0.35
# min        NaN              NaN        0.00
# 25%        NaN              NaN        0.00
# 50%        NaN              NaN        0.00
# 75%        NaN              NaN        0.00
# max        NaN              NaN        1.00

# %%
def convert_to_num(data):
    data_copy = data.copy()
    object_cols = [col for col in data.columns if data[col].dtype == "object"]
    for col in object_cols:
        label = data[col].unique().tolist()
        data_copy[col] = data[col].apply(lambda x: label.index(x))
        dic = dict()
        for i, x in enumerate(label):
            dic[x] = i
        print('{} : {}'.format(col, dic))
    return data_copy

# %%
df = convert_to_num(data)
# Out:
# zip_code : {'Surburban': 0, 'Rural': 1, 'Urban': 2}
# channel : {'Phone': 0, 'Web': 1, 'Multichannel': 2}
# offer : {'Buy One Get One': 0, 'No Offer': 1, 'Discount': 2}

# %%
df = df.rename(columns={'conversion': 'target'})
df = df.rename(columns={'offer': 'treatment'})

# %%
df.describe(include = 'all')
# Out:
#         recency   history  used_discount  used_bogo  zip_code  is_referral  \
# count 64,000.00 64,000.00      64,000.00  64,000.00 64,000.00    64,000.00
# mean       5.76    242.09           0.55       0.55      0.95         0.50
# std        3.51    256.16           0.50       0.50      0.92         0.50
# min        1.00     29.99           0.00       0.00      0.00         0.00
# 25%        2.00     64.66           0.00       0.00      0.00         0.00
# 50%        6.00    158.11           1.00       1.00      1.00         1.00
# 75%        9.00    325.66           1.00       1.00      2.00         1.00
# max       12.00  3,345.93           1.00       1.00      2.00         1.00
#
#         channel  treatment    target
# count 64,000.00  64,000.00 64,000.00
# mean       0.68       1.00      0.15
# std        0.68       0.82      0.35
# min        0.00       0.00      0.00
# 25%        0.00       0.00      0.00
# 50%        1.00       1.00      0.00
# 75%        1.00       2.00      0.00
# max        2.00       2.00      1.00

# %%
df.to_csv('../data/customer_retention/data_treated.csv', index = False)
