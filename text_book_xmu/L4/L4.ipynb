# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # 数据预览和预处理

# %%
stock = pd.read_csv("./data/Tesla.csv")
stock.head()
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
stock['Date'] = pd.to_datetime(stock['Date'])
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1692 non-null   datetime64[ns]
#  1   Open       1692 non-null   float64
#  2   High       1692 non-null   float64
#  3   Low        1692 non-null   float64
#  4   Close      1692 non-null   float64
#  5   Volume     1692 non-null   int64
#  6   Adj Close  1692 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 92.7 KB

# %%
stock.describe(include = 'all', datetime_is_numeric=True)
# Out:
#                                 Date         Open         High          Low  \
# count                           1692  1692.000000  1692.000000  1692.000000
# mean   2013-11-06 02:53:37.021276416   132.441572   134.769698   129.996223
# min              2010-06-29 00:00:00    16.139999    16.629999    14.980000
# 25%              2012-03-01 18:00:00    30.000000    30.650000    29.215000
# 50%              2013-11-05 12:00:00   156.334999   162.370002   153.150002
# 75%              2015-07-14 06:00:00   220.557495   224.099999   217.119999
# max              2017-03-17 00:00:00   287.670013   291.420013   280.399994
# std                              NaN    94.309923    95.694914    92.855227
#
#              Close        Volume    Adj Close
# count  1692.000000  1.692000e+03  1692.000000
# mean    132.428658  4.270741e+06   132.428658
# min      15.800000  1.185000e+05    15.800000
# 25%      29.884999  1.194350e+06    29.884999
# 50%     158.160004  3.180700e+06   158.160004
# 75%     220.022503  5.662100e+06   220.022503
# max     286.040009  3.716390e+07   286.040009
# std      94.313187  4.295971e+06    94.313187

# %%
plt.figure(figsize = (20, 5))
day = np.arange(0, stock.shape[0], 1) #按天数依次排列
plt.plot(day, stock['Close'])
plt.title("Close Tesla Price") #为了不进行字体转换建议全英文绘制
plt.grid(which = "major", axis = "y")
plt.show()

# %% [markdown]
# 对于RNN及相关算法的模型,我们需要一个参数: time_step. 这样我们就可以使模型在预测时仅考虑time_step内的价格,从而大幅度减小过于久远的历史交易数据对未来数据的影响
#
# 这里设置time_step = 5(若无特殊节假日,美股5天=一周,周六周日休市)

# %%
time_step = 5
day_to_predict = 30 # 需要预测多少天的股价
data_to_use = stock['Close'].values

scaler = StandardScaler()
scaled_stock = scaler.fit_transform(data_to_use.reshape(-1, 1)) #-1的意思是这里的形状留空,由其余维度的形状计算得出.若有20个数据,则(-1, 1)会将其变为20列,1行;(1, -1)会将其变为20行,一列.如果不使用reshape,后面的截断会报错

train = scaled_stock[:-day_to_predict]
test = scaled_stock[-day_to_predict - time_step:]

print("训练集一共有{}天的股价数据".format(train.shape[0]))
print("测试集一共有{}天的股价数据".format(test.shape[0]))
# Out:
# 训练集一共有1662天的股价数据
# 测试集一共有35天的股价数据

# %%
train_x, train_y = [], []
for i in range(time_step, train.shape[0]) : 
    train_x.append(train[i - time_step : i, 0]) #前五天作为变量
    train_y.append(train[i, 0]) #后一天作为预测

train_x, train_y = np.array(train_x), np.array(train_y) #转为numpy array,否则是list
print(train_x[:5]) #train_x的前五个元素长这样
print(train_x.shape)
print('-------------')
print(train_y[:5]) #train_y的前五个元素长这样
print(train_y.shape)
# Out:
# [[-1.15117251 -1.15180886 -1.17164229 -1.20091512 -1.23368799]
#  [-1.15180886 -1.17164229 -1.20091512 -1.23368799 -1.23697589]
#  [-1.17164229 -1.20091512 -1.23368799 -1.23697589 -1.21936977]
#  [-1.20091512 -1.23368799 -1.23697589 -1.21936977 -1.22000613]
#  [-1.23368799 -1.23697589 -1.21936977 -1.22000613 -1.22371827]]
# (1657, 5)
# -------------
# [-1.23697589 -1.21936977 -1.22000613 -1.22371827 -1.21215762]
# (1657,)

# %%
# 对于test如法炮制
test_x, test_y = [], []
for i in range(time_step, test.shape[0]) : 
    test_x.append(test[i - time_step : i, 0])
    test_y.append(test[i, 0])
test_x, test_y = np.array(test_x), np.array(test_y)

# %% [markdown]
# reshape一下以适用于tensorflow

# %%
train_x = np.reshape(train_x, (train_x.shape[0], train_x.shape[1], 1))
test_x = np.reshape(test_x, (test_x.shape[0],test_x.shape[1], 1))

# %%
train_x.shape
# Out:
# (1657, 5, 1)

# %% [markdown]
# # 建模

# %%
import tensorflow as tf
from tensorflow.keras import callbacks
from tensorflow.keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam #综合来讲adam是目前最常用的优化器.sgd虽然能达到极小值,但耗时较长,且容易陷入局部极小值

# %%
reduce_lr = callbacks.ReduceLROnPlateau(monitor= "loss", factor = 0.5, patience = 10,
                                                 min_lr = 0.000001, verbose = 1)
monitor_es = callbacks.EarlyStopping(monitor= "loss", patience = 25, restore_best_weights= False, verbose = True)

# %%
model = Sequential() #建立一个空模型

# 添加各种层
model.add(LSTM(units = 128, return_sequences = True, input_shape = (train_x.shape[1], 1,))) #留空是因为使用了批次输入,这里留空会在打印model summary中被计为None
# 参数数量=4 * ((units * units) + (units * inputs) + units_bias), 其中unit_bias是Σwx+b中的b,数量等于units
# 乘以4是因为,lstm与simple rnn相比多了更新门,遗忘门和输出门
# 第一层的inputs是1,因为只输入一天的股价
model.add(Dropout(0.2))
model.add(LSTM(units = 128, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 128, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 128, return_sequences = False))
model.add(Dropout(0.2))

model.add(Dense(units = 20, activation = "relu"))
model.add(Dense(units = 1, activation = "relu"))

# 关于优化方法的比较,详见: https://ruder.io/optimizing-gradient-descent/
model.compile(Adam(lr = 0.001), loss = ["mean_squared_error"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 128)            66560
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 128)            131584
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 5, 128)            131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 20)                2580
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 463,913
# Trainable params: 463,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_history = model.fit(train_x, train_y, epochs = 300, batch_size = 16, callbacks = [reduce_lr, monitor_es])
# Out:
# Epoch 1/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5662
# Epoch 2/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5304
# Epoch 3/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5306
# Epoch 4/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5319
# Epoch 5/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5294
# Epoch 6/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5310
# Epoch 7/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5294
# Epoch 8/300
# 104/104 [==============================] - 1s 9ms/step - loss: 0.5314
# Epoch 9/300
# 104/104 [==============================] - 1s 9ms/step - loss: 0.5288
# Epoch 10/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5287
# Epoch 11/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5280
# Epoch 12/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5272
# Epoch 13/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5279
# Epoch 14/300
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5269
# Epoch 15/300
# 104/104 [==============================] - 1s 13ms/step - loss: 0.5273
# Epoch 16/300
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5257
# Epoch 17/300
# 104/104 [==============================] - 1s 13ms/step - loss: 0.5257
# Epoch 18/300
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5252
# Epoch 19/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5253
# Epoch 20/300
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5247
# Epoch 21/300
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5248
# Epoch 22/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5244
# Epoch 23/300
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5248
# Epoch 24/300
# 104/104 [==============================] - 1s 13ms/step - loss: 0.5246
# Epoch 25/300
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5247
# Epoch 26/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5243
# Epoch 27/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5245
# Epoch 28/300
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5240
# Epoch 29/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5247
# Epoch 30/300
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5245
# Epoch 31/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5241
# Epoch 32/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5243
# Epoch 33/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5245
# Epoch 34/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5249
# Epoch 35/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5242
# Epoch 36/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5239
# Epoch 37/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5245
# Epoch 38/300
# 103/104 [============================>.] - ETA: 0s - loss: 0.5231
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5240
# Epoch 39/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5236
# Epoch 40/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5238
# Epoch 41/300
# 104/104 [==============================] - 1s 9ms/step - loss: 0.5237
# Epoch 42/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5235
# Epoch 43/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5237
# Epoch 44/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5238
# Epoch 45/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5237
# Epoch 46/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5236
# Epoch 47/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5234
# Epoch 48/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5235
# Epoch 49/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5238
# Epoch 50/300
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5237
# Epoch 51/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5237
# Epoch 52/300
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5233
# Epoch 53/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5236
# Epoch 54/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5235
# Epoch 55/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5238
# Epoch 56/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5234
# Epoch 57/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5237
# Epoch 58/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5237
# Epoch 59/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5238
# Epoch 60/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5237
# Epoch 61/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5238
# Epoch 62/300
# 100/104 [===========================>..] - ETA: 0s - loss: 0.5231
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5237
# Epoch 63/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5234
# Epoch 64/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5236
# Epoch 65/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5233
# Epoch 66/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5233
# Epoch 67/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5234
# Epoch 68/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5234
# Epoch 69/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 70/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5234
# Epoch 71/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5234
# Epoch 72/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5233
# Epoch 73/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5234
# Epoch 74/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5232
# Epoch 75/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5233
# Epoch 76/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5234
# Epoch 77/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5233
# Epoch 78/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5234
# Epoch 79/300
# 100/104 [===========================>..] - ETA: 0s - loss: 0.5249
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 104/104 [==============================] - 1s 9ms/step - loss: 0.5233
# Epoch 80/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 81/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 82/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5233
# Epoch 83/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 84/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 85/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5232
# Epoch 86/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5232
# Epoch 87/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5233
# Epoch 88/300
# 104/104 [==============================] - 1s 9ms/step - loss: 0.5232
# Epoch 89/300
# 104/104 [==============================] - ETA: 0s - loss: 0.5232
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 90/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 91/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 92/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5232
# Epoch 93/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5231
# Epoch 94/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5232
# Epoch 95/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5231
# Epoch 96/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5231
# Epoch 97/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5232
# Epoch 98/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5231
# Epoch 99/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 100/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 101/300
# 104/104 [==============================] - ETA: 0s - loss: 0.5231
# Epoch 00101: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5231
# Epoch 102/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 103/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 104/300
# 104/104 [==============================] - 1s 9ms/step - loss: 0.5232
# Epoch 105/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 106/300
# 104/104 [==============================] - 1s 9ms/step - loss: 0.5231
# Epoch 107/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5232
# Epoch 108/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5230
# Epoch 109/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5232
# Epoch 110/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 111/300
# 100/104 [===========================>..] - ETA: 0s - loss: 0.5273
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 112/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 113/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5232
# Epoch 114/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5231
# Epoch 115/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5231
# Epoch 116/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5230
# Epoch 117/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 118/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5230
# Epoch 119/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 120/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 121/300
# 103/104 [============================>.] - ETA: 0s - loss: 0.5225
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 122/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 123/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5230
# Epoch 124/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5230
# Epoch 125/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 126/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5231
# Epoch 127/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5231
# Epoch 128/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 129/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5230
# Epoch 130/300
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5231
# Epoch 131/300
# 104/104 [==============================] - ETA: 0s - loss: 0.5231
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 132/300
# 104/104 [==============================] - 1s 13ms/step - loss: 0.5231
# Epoch 133/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 134/300
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5231
# Epoch 135/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 136/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5230
# Epoch 137/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5231
# Epoch 138/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5231
# Epoch 139/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 140/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5230
# Epoch 141/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 142/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 143/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5230
# Epoch 144/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5230
# Epoch 145/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5230
# Epoch 146/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5230
# Epoch 147/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5232
# Epoch 148/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 149/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 150/300
# 102/104 [============================>.] - ETA: 0s - loss: 0.5213
# Epoch 00150: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5230
# Epoch 151/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5230
# Epoch 152/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 153/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 154/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 155/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5230
# Epoch 156/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 157/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5230
# Epoch 158/300
# 104/104 [==============================] - 1s 9ms/step - loss: 0.5231
# Epoch 159/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5231
# Epoch 160/300
# 100/104 [===========================>..] - ETA: 0s - loss: 0.5239
# Epoch 00160: ReduceLROnPlateau reducing learning rate to 1e-06.
# 104/104 [==============================] - 1s 12ms/step - loss: 0.5232
# Epoch 161/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 162/300
# 104/104 [==============================] - 1s 9ms/step - loss: 0.5231
# Epoch 163/300
# 104/104 [==============================] - 1s 10ms/step - loss: 0.5231
# Epoch 164/300
# 104/104 [==============================] - 1s 9ms/step - loss: 0.5230
# Epoch 165/300
# 104/104 [==============================] - 1s 11ms/step - loss: 0.5231
# Epoch 00165: early stopping

# %%
plt.figure(figsize = (20, 5))
plt.plot(train_history.history["loss"])
plt.title("Loss among epochs")
plt.show()

# %% [markdown]
# # 模型的存储

# %%
import os

# %%
if not os.path.exists('./model'):
    os.mkdir('./model')
model_json = model.to_json()
# .json保存model structure
with open("./model/tesla.json", "w") as json_file:
  json_file.write(model_json)
# .h5保存model weights
model.save_weights("./model/tesla.h5")

# %%
from tensorflow.keras.models import model_from_json

json_file = open('./model/tesla.json', 'r')
loaded_model_json = json_file.read()
json_file.close()

loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights("./model/tesla.h5")
print("模型已加载")
# Out:
# 模型已加载

# %%
loaded_model.compile(loss='mean_squared_error', optimizer='adam')

# %%
real_prices = test[time_step:]
real_prices = scaler.inverse_transform(real_prices) #还原

# %% [markdown]
# 结果比较

# %%
predicted_prices = loaded_model.predict(test_x)
predicted_prices = scaler.inverse_transform(predicted_prices)

x = np.arange(0, day_to_predict, 1)

plt.figure(figsize = (15, 5))
plt.plot(x, real_prices, color = "red", label = "Real Tesla Prices")
plt.plot(x, predicted_prices, color = "blue", label = "Predicted Tesla Prices")
plt.title("Tesla Stock Prices", fontsize = 18)
plt.legend()
# 设置刻度,以一天为单位
x_major_locator=plt.MultipleLocator(1)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.grid(which = "major", axis = "both")
plt.show()
